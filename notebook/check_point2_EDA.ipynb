# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import numpy as np

# %%
conn = sqlite3.connect("process.db")
df = pd.read_sql_query("select * from COUNTERS_DOUBLE_TIME_DATA;", conn)
df.sample(10)
# Out:
#             MEASUREMENT_TIME  ID_INPUT    VALUE PRIVATE_DATA
# 311  2020-11-07 02:43:31.412        19  0.00000         9644
# 328  2020-11-07 02:43:31.498        18  0.00000         1988
# 505  2020-11-07 02:43:31.671        19  0.59375        24224
# 510  2020-11-07 02:43:31.672        18  0.00000        17776
# 157  2020-11-07 02:43:31.281        19  0.00000        12080
# 366  2020-11-07 02:43:31.539        18  0.00000         7432
# 435  2020-11-07 02:43:31.615        19  0.00000        19272
# 532  2020-11-07 02:43:31.675        18  0.00000        27700
# 207  2020-11-07 02:43:31.305        19  2.18750         5064
# 128  2020-11-07 02:43:31.255        18  0.00000         3492

# %%
plt.bar(df['ID_INPUT'],df['VALUE'])
#input id 18 has value, input id 19 is always 0
# Out:
# <BarContainer object of 574 artists>

# %%
id18 = df.loc[df["ID_INPUT"] == 18]
plt.plot(id18["VALUE"])
print(np.max(id18["VALUE"]))
#the values with id 18 is mostly around 0 but the max is around 5000
# Out:
# 5378.65625

# %%
deviceconn = sqlite3.connect("device.db")
dev_string_df = pd.read_sql_query("select * from COUNTERS_STRING_TIME_DATA;", deviceconn)
dev_ull_df = pd.read_sql_query("select * from COUNTERS_ULL_TIME_DATA;", deviceconn)

# %%
dev_string_df.sample(10)
# Out:
#             MEASUREMENT_TIME  ID_INPUT                         VALUE  \
# 77   2020-11-07 02:14:51.590         2           HID Keyboard Device
# 29   2020-11-07 02:14:51.590         2
# 54   2020-11-07 02:14:51.590         0         GUID_DEVINTERFACE_HID
# 140  2020-11-07 02:14:51.590         2       WDC  WDS100T2B0A-00SM50
# 121  2020-11-07 02:14:51.590         1               ms_l2tpminiport
# 110  2020-11-07 02:14:51.590         2             WAN Miniport (IP)
# 51   2020-11-07 02:14:51.590         0         GUID_DEVINTERFACE_HID
# 165  2020-11-07 02:14:51.590         0  GUID_DEVINTERFACE_USB_DEVICE
# 155  2020-11-07 02:14:51.590         2
# 56   2020-11-07 02:14:51.590         2           HID Keyboard Device
#
#     PRIVATE_DATA
# 77            26
# 29            10
# 54            19
# 140           47
# 121           41
# 110           37
# 51            18
# 165           56
# 155           52
# 56            19

# %%
dev_ull_df.sample(10)
# Out:
#            MEASUREMENT_TIME  ID_INPUT  VALUE PRIVATE_DATA
# 19  2020-11-07 02:14:51.590         3      4           20
# 18  2020-11-07 02:14:51.590         3      4           19
# 47  2020-11-07 02:14:51.590         3      4           48
# 6   2020-11-07 02:14:51.590         3      4            7
# 27  2020-11-07 02:14:51.590         3      4           28
# 8   2020-11-07 02:14:51.590         3      4            9
# 13  2020-11-07 02:14:51.590         3      4           14
# 52  2020-11-07 02:14:51.590         3      4           53
# 30  2020-11-07 02:14:51.590         3      4           31
# 36  2020-11-07 02:14:51.590         3      4           37

# %%
counts = dev_string_df.groupby(dev_string_df['VALUE']).agg('count')#.apply(lambda x: np.count(x))
counts
# There are 78 differnt device input
# Out:
#                                                  MEASUREMENT_TIME  ID_INPUT  \
# VALUE
#                                                                22        22
# ACPI\VEN_PNP&DEV_0501                                           3         3
# Broadcom BCM20702 Bluetooth 4.0 USB Device                      1         1
# CT500MX500SSD1                                                  1         1
# GUID_DEVINTERFACE_COMPORT                                       1         1
# GUID_DEVINTERFACE_DISK                                          2         2
# GUID_DEVINTERFACE_DISPLAY_ADAPTER                               2         2
# GUID_DEVINTERFACE_HID                                          18        18
# GUID_DEVINTERFACE_KEYBOARD                                      4         4
# GUID_DEVINTERFACE_MONITOR                                       1         1
# GUID_DEVINTERFACE_MOUSE                                         4         4
# GUID_DEVINTERFACE_NET                                          12        12
# GUID_DEVINTERFACE_PORTS                                         1         1
# GUID_DEVINTERFACE_SERENUM_BUS_ENUMERATOR                        1         1
# GUID_DEVINTERFACE_STORAGEPORT                                   2         2
# GUID_DEVINTERFACE_USB_DEVICE                                    4         4
# GUID_DEVINTERFACE_VOLUME                                        4         4
# GUID_DISPLAY_DEVICE_ARRIVAL                                     2         2
# HID Keyboard Device                                             8         8
# HID-compliant mouse                                             8         8
# HID\VID_046D&PID_C08B&REV_2702&MI_00                            2         2
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col01                      2         2
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col02                      1         1
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col03                      1         1
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col04                      1         1
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col05                      1         1
# HID\VID_046D&PID_C231                                           2         2
# HID\VID_046D&PID_C232                                           2         2
# HID\VID_2F68&PID_0082&REV_0107&MI_00&Col01                      2         2
# HID\VID_2F68&PID_0082&REV_0107&MI_00&Col02                      1         1
# ...                                                           ...       ...
# SCSI\DiskWDC_____WDS100T2B0A-00SM4110                           1         1
# SCSI\Disk__________CT500MX500SSD1M3CR                           1         1
# STORAGE\Volume                                                  4         4
# TAP-Windows Adapter V9                                          1         1
# USB Composite Device                                            3         3
# USB\VID_046D&PID_C08B&REV_2702                                  1         1
# USB\VID_0A5C&PID_21E8&REV_0112                                  1         1
# USB\VID_1BCF&PID_2284&REV_0005                                  1         1
# USB\VID_2F68&PID_0082&REV_0107                                  1         1
# WAN Miniport (IKEv2)                                            1         1
# WAN Miniport (IP)                                               1         1
# WAN Miniport (IPv6)                                             1         1
# WAN Miniport (L2TP)                                             1         1
# WAN Miniport (Network Monitor)                                  1         1
# WAN Miniport (PPPOE)                                            1         1
# WAN Miniport (PPTP)                                             1         1
# WAN Miniport (SSTP)                                             1         1
# WDC  WDS100T2B0A-00SM50                                         1         1
# ms_agilevpnminiport                                             1         1
# ms_l2tpminiport                                                 1         1
# ms_ndiswanbh                                                    1         1
# ms_ndiswanip                                                    1         1
# ms_ndiswanipv6                                                  1         1
# ms_pppoeminiport                                                1         1
# ms_pptpminiport                                                 1         1
# ms_sstpminiport                                                 1         1
# tap0901                                                         1         1
# vms_mp                                                          1         1
# vms_vsmp                                                        1         1
# {8e7bd593-6e6c-4c52-86a6-77175494dd8e}\MsVhdHba                 1         1
#
#                                                  PRIVATE_DATA
# VALUE
#                                                            22
# ACPI\VEN_PNP&DEV_0501                                       3
# Broadcom BCM20702 Bluetooth 4.0 USB Device                  1
# CT500MX500SSD1                                              1
# GUID_DEVINTERFACE_COMPORT                                   1
# GUID_DEVINTERFACE_DISK                                      2
# GUID_DEVINTERFACE_DISPLAY_ADAPTER                           2
# GUID_DEVINTERFACE_HID                                      18
# GUID_DEVINTERFACE_KEYBOARD                                  4
# GUID_DEVINTERFACE_MONITOR                                   1
# GUID_DEVINTERFACE_MOUSE                                     4
# GUID_DEVINTERFACE_NET                                      12
# GUID_DEVINTERFACE_PORTS                                     1
# GUID_DEVINTERFACE_SERENUM_BUS_ENUMERATOR                    1
# GUID_DEVINTERFACE_STORAGEPORT                               2
# GUID_DEVINTERFACE_USB_DEVICE                                4
# GUID_DEVINTERFACE_VOLUME                                    4
# GUID_DISPLAY_DEVICE_ARRIVAL                                 2
# HID Keyboard Device                                         8
# HID-compliant mouse                                         8
# HID\VID_046D&PID_C08B&REV_2702&MI_00                        2
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col01                  2
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col02                  1
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col03                  1
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col04                  1
# HID\VID_046D&PID_C08B&REV_2702&MI_01&Col05                  1
# HID\VID_046D&PID_C231                                       2
# HID\VID_046D&PID_C232                                       2
# HID\VID_2F68&PID_0082&REV_0107&MI_00&Col01                  2
# HID\VID_2F68&PID_0082&REV_0107&MI_00&Col02                  1
# ...                                                       ...
# SCSI\DiskWDC_____WDS100T2B0A-00SM4110                       1
# SCSI\Disk__________CT500MX500SSD1M3CR                       1
# STORAGE\Volume                                              4
# TAP-Windows Adapter V9                                      1
# USB Composite Device                                        3
# USB\VID_046D&PID_C08B&REV_2702                              1
# USB\VID_0A5C&PID_21E8&REV_0112                              1
# USB\VID_1BCF&PID_2284&REV_0005                              1
# USB\VID_2F68&PID_0082&REV_0107                              1
# WAN Miniport (IKEv2)                                        1
# WAN Miniport (IP)                                           1
# WAN Miniport (IPv6)                                         1
# WAN Miniport (L2TP)                                         1
# WAN Miniport (Network Monitor)                              1
# WAN Miniport (PPPOE)                                        1
# WAN Miniport (PPTP)                                         1
# WAN Miniport (SSTP)                                         1
# WDC  WDS100T2B0A-00SM50                                     1
# ms_agilevpnminiport                                         1
# ms_l2tpminiport                                             1
# ms_ndiswanbh                                                1
# ms_ndiswanip                                                1
# ms_ndiswanipv6                                              1
# ms_pppoeminiport                                            1
# ms_pptpminiport                                             1
# ms_sstpminiport                                             1
# tap0901                                                     1
# vms_mp                                                      1
# vms_vsmp                                                    1
# {8e7bd593-6e6c-4c52-86a6-77175494dd8e}\MsVhdHba             1
#
# [78 rows x 3 columns]

# %%
plt.plot(counts['ID_INPUT'])

# %%
batconn = sqlite3.connect("battery.db")
batdf = pd.read_sql_query("select * from INPUTS;", batconn)

# %%
batdf
#The inputs for battery
# Out:
#    ID_INPUT  ID_INPUT_LIBRARY  ID_BLOB_INPUT  INDEX_IN_BLOB       INPUT_NAME  \
# 0         0                 0              0              0  ACPI-BATTERY(0)
# 1         1                 0              0              0  ACPI-BATTERY(1)
#
#                 INPUT_DESCRIPTION  INPUT_TYPE   INPUT_CATALOG_TIME_UTC  \
# 0          ACPI-BATTERY:::AC_DC::           1  2020-11-07 02:09:26.785
# 1  ACPI-BATTERY:::BATTERY_COUNT::           1  2020-11-07 02:09:26.785
#
#                                    GUID
# 0  02697fb9-7557-4e7d-b005-bd7121913652
# 1  0945b713-bd24-4672-b130-96ac7a4a7eff

# %%
userconn = sqlite3.connect("user wait.db")
userdf = pd.read_sql_query("select * from COUNTERS_STRING_TIME_DATA;", userconn)
userdf.sample(10)
# Out:
#            MEASUREMENT_TIME  ID_INPUT      VALUE PRIVATE_DATA
# 16  2020-11-07 02:29:52.186         0      OTHER            0
# 15  2020-11-07 02:29:51.986         0  INVISIBLE            0
# 18  2020-11-07 02:29:52.686         0      OTHER            0
# 13  2020-11-07 02:29:50.786         0  INVISIBLE            0
# 0   2020-11-07 02:29:41.187         0      OTHER            0
# 4   2020-11-07 02:29:47.686         0      OTHER            0
# 28  2020-11-07 02:31:53.686         0      OTHER            0
# 21  2020-11-07 02:29:58.186         0  INVISIBLE            0
# 17  2020-11-07 02:29:52.586         0  INVISIBLE            0
# 12  2020-11-07 02:29:50.686         0      OTHER            0

# %%
userdf.groupby('VALUE').agg('count')
# Out:
#            MEASUREMENT_TIME  ID_INPUT  PRIVATE_DATA
# VALUE
# INVISIBLE                14        14            14
# OTHER                    15        15            15
